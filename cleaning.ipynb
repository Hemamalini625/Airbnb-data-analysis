# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd

data = pd.DataFrame({
    'latitude': [37.7749, 34.0522, 40.7128],
    'longitude': [-122.4194, -118.2437, -74.0060]
})
 
## Create a map with the data
st.map(data)

# %%
import csv
import pandas as pd
df = pd.read_csv('C:/Users/Hema Chandran/anacond/pkgs/ipykernel-6.25.0-py311h746a85d_0/Lib/site-packages/airbnb/sample_airbnb.listingsAndReviews.csv',low_memory = False)
dfcopy = df.copy(deep = False)
#dfcopy.dropDuplicates()
#print(df.columns)
print(df)
print(df.shape)
dfcopy.dropna(how='any')
print(dfcopy.shape)
# Out:
#            _id                            listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name  \
# 0                               Ribeira Charming Duplex
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                              Private Room in Bushwick
# ...

# %%
df.columns
# Out:
# Index(['_id', 'listing_url', 'name', 'summary', 'space', 'description',
#        'neighborhood_overview', 'notes', 'transit', 'access',
#        ...
#        'reviews[526].comments', 'reviews[527].comments',
#        'reviews[528].comments', 'reviews[529].comments',
#        'reviews[530].comments', 'reviews[531].comments',
#        'reviews[532].comments', 'weekly_price', 'monthly_price',
#        'reviews_per_month'],
#       dtype='object', length=3361)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Columns: 3361 entries, _id to reviews_per_month
# dtypes: bool(4), float64(1622), int64(13), object(1722)
# memory usage: 142.3+ MB

# %%
group_host_name = df.groupby('name')
hostid_plot=df['name'].value_counts()

# %%
df[['name'],['neighborhood_overview']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anacond\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anacond\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anacond\Lib\site-packages\pandas\_libs\index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['name'], ['neighborhood_overview'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df[['name'],['neighborhood_overview']]
#
# File ~\anacond\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
# ...

# %%
df['name']
# Out:
# 0                                 Ribeira Charming Duplex
# 1                            Horto flat with small garden
# 2                        Ocean View Waikiki Marina w/prkg
# 3                                Private Room in Bushwick
# 4                             Apt Linda Vista Lagoa - Rio
#                               ...
# 5550                        Cozy apartment downtown Porto
# 5551                                      Kadıköy-Altıyol
# 5552         The best suite in Copacabana (total privacy)
# 5553       March Madness Special! Aina Nalu Platinum D107
# 5554    Just Steps from the Ocean at Premier Platinum ...
# Name: name, Length: 5555, dtype: object

# %%
#find percentage of missing values for each column
listings_missing_df = df.isnull().mean()*100

#filter out only columns, which have missing values
listings_columns_with_nan = listings_missing_df[listings_missing_df > 0]

#plot the results
listings_columns_with_nan.plot.bar(title='Missing values per column, %')
# Out:
# <Axes: title={'center': 'Missing values per column, %'}>

# %%
df=df.fillna(0)

# %%
import matplotlib as plt
# %matplotlib inline
import seaborn as sns
data3 = {'count_id':df['_id'].value_counts() }
gkk = pd.DataFrame(data3)
#plt.figure(figsize=(60,15))
gkk.head()
from matplotlib.pyplot import figure
plt.rcParams['figure.figsize'] = (45, 15)
#plt.figure(figsize=(1,15))
gkk.iloc[0:10].plot.bar(color=['yellow'])
plt.xticks(fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 12
#      10 #plt.figure(figsize=(1,15))
#      11 gkk.iloc[0:10].plot.bar(color=['yellow'])
# ---> 12 plt.xticks(fontsize=15)
#
# File ~\anacond\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'xticks'

# %%
from matplotlib.pyplot import figure
plt.rcParams['figure.figsize'] = (20, 10)
#plt.figure(figsize=(1,15))
gkk.iloc[0:40].plot.bar()
plt.xticks(fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 5
#       3 #plt.figure(figsize=(1,15))
#       4 gkk.iloc[0:40].plot.bar()
# ----> 5 plt.xticks(fontsize=15)
#
# File ~\anacond\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'xticks'
